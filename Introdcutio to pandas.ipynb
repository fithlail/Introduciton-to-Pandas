# %% [markdown]
# Introduction to Pandas - Dphi Tech

# %% [markdown]
# Series

# %%
import pandas as pd
l = [1, 1, 2, 3, 5, 8, 13]
pd.Series(l)
# Out:
# 0     1
# 1     1
# 2     2
# 3     3
# 4     5
# 5     8
# 6    13
# dtype: int64

# %%
import pandas as pd
l = {'one' : 1, 'two' : 2, 'three' : 3, 'four' : 4, 'five' : 5, 'six' : 6, 'seven' : 7 }
pd.Series(l)
# Out:
# one      1
# two      2
# three    3
# four     4
# five     5
# six      6
# seven    7
# dtype: int64
